# %% [markdown]
# <a href="https://colab.research.google.com/github/dokluch/GAN-explorer/blob/main/GAN_explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make sure you have runtime -> GPU

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/gTiukX6auX0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %%
# %cd /content/
# !mkdir models sequence renders sequence_upscale
# !mkdir models/stylegan2 models/ISR
# !git clone https://github.com/dokluch/GAN-explorer.git

# %cd /content/GAN-explorer/
# !pip install -r requirements.txt
# !python download.py --models all --out /content/models/
from gan_explorer import *

# %cd /content/
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch
# %cd stylegan2-ada-pytorch

clear_output()

# %% [markdown]
# Imports and stuff

# %%
prefix = "Faces" #prefix for the rendered animation
sequence_folder = "/content/sequence"
render_folder = "/content/renders"
models_folder = "/content/models/stylegan2"

# %%
current_model = stylegan2_ada_model()
global_seeds = seeds_updater()
global_settings = settings_updater()
current_model.update_prefix(prefix)

bttns, output_model_select = get_model_loader(current_model, models_folder)
display(bttns, output_model_select)
# Out:
# ...
# Output()

# %% [markdown]
# The first model is pre-loaded automatically

# %%
output, buttons_line_1, buttons_line_2, output2 = get_timeline_controls(current_model, global_seeds, global_settings)
display(output, buttons_line_1, buttons_line_2, output2)

sliders, bttns, output3 = get_render_controls(current_model, global_seeds, sequence_folder, render_folder)
display(sliders, bttns, output3)
# Out:
# Output()
# ...
# Output()
# ...
# Output()
