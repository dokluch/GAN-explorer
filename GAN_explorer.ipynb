# %% [markdown]
# <a href="https://colab.research.google.com/github/dokluch/GAN-explorer/blob/main/GAN_explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Загружаем модельки. Сперва убедись что у тебя runtime -> GPU
#
# Запусти следующий блок, чтобы посмотреть видео

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/gTiukX6auX0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/gTiukX6auX0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# %cd /content/
# !pip install ipyplot click psutil scipy requests tqdm pyspng ninja imageio imageio-ffmpeg==0.4.3 

# !rm -rf ./GAN-explorer/
# !mkdir models sequence renders
# !git clone https://github.com/dokluch/GAN-explorer.git

# %cd /content/GAN-explorer/
# !python download.py --models all --out /content/models
from gan_explorer import *

# %cd /content/
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch
# %cd stylegan2-ada-pytorch

clear_output()

# %% [markdown]
# Все импорты

# %%
prefix = "Faces"

# %%
current_model = stylegan2_ada_model()
seeds_updater = seeds_updater()
current_model.update_prefix(prefix)

bttns, output_model_select = get_model_loader(current_model)
display(bttns, output_model_select)
# Out:
# ...
# Output()

# %% [markdown]
# Ткни в "Load Model"

# %%
output, buttons_line_1, buttons_line_2, output2 = get_timeline_controls(current_model, seeds_updater)
display(output, buttons_line_1, buttons_line_2, output2)

sliders, bttns, output3 = get_render_controls(current_model, seeds_updater)
display(sliders, bttns, output3)
# Out:
# Output()
# ...
# Output()
# ...
# Output()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/GAN-explorer/gan_explorer.py in on_reset(b)
#     140
#     141     def on_reset(b):
# --> 142         with output2:
#     143             seeds_updater.reset()
#     144             display_seeds_as_imgs()
#
# TypeError: 'Output' object is not callable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/GAN-explorer/gan_explorer.py in on_reset(b)
#     140
#     141     def on_reset(b):
# --> 142         with output2:
#     143             seeds_updater.reset()
#     144             display_seeds_as_imgs()
#
# TypeError: 'Output' object is not callable
# ---------------------------------------------------------------------------
# ...
